# %% [markdown]
# # Preparing the dataset for hippocampus segmentation
#
# In this notebook you will use the skills and methods that we have talked about during our EDA Lesson to prepare the hippocampus dataset using Python. Follow the Notebook, writing snippets of code where directed so using Task comments, similar to the one below, which expects you to put the proper imports in place. Write your code directly in the cell with TASK comment. Feel free to add cells as you see fit, but please make sure that code that performs that tasked activity sits in the same cell as the Task comment.

# %%
# TASK: Import the following libraries that we will use: nibabel, matplotlib, numpy
import numpy as np 
import nibabel as nib
import matplotlib.pyplot as plt
import os
import glob
import shutil

# %% [markdown]
# It will help your understanding of the data a lot if you were able to use a tool that allows you to view NIFTI volumes, like [3D Slicer](https://www.slicer.org/). I will refer to Slicer throughout this Notebook and will be pasting some images showing what your output might look like.

# %% [markdown]
# ## Loading NIFTI images using NiBabel
#
# NiBabel is a python library for working with neuro-imaging formats (including NIFTI) that we have used in some of the exercises throughout the course. Our volumes and labels are in NIFTI format, so we will use nibabel to load and inspect them.
#
# NiBabel documentation could be found here: https://nipy.org/nibabel/
#
# Our dataset sits in two directories - *images* and *labels*. Each image is represented by a single file (we are fortunate to have our data converted to NIFTI) and has a corresponding label file which is named the same as the image file.
#
# Note that our dataset is "dirty". There are a few images and labels that are not quite right. They should be quite obvious to notice, though. The dataset contains an equal amount of "correct" volumes and corresponding labels, and you don't need to alter values of any samples in order to get the clean dataset.

# %%
os.listdir('../../data/TrainingSet/labels')
# Out:
# ['hippocampus_376.nii.gz',
#  'hippocampus_165.nii.gz',
#  'hippocampus_286.nii.gz',
#  'hippocampus_152.nii.gz',
#  'hippocampus_176.nii.gz',
#  'hippocampus_096.nii.gz',
#  'hippocampus_068.nii.gz',
#  'hippocampus_289.nii.gz',
#  'hippocampus_260.nii.gz',
#  'hippocampus_171.nii.gz',
#  'hippocampus_296.nii.gz',
#  'hippocampus_142.nii.gz',
#  'hippocampus_375.nii.gz',
#  'hippocampus_097.nii.gz',
#  'hippocampus_064.nii.gz',
#  'hippocampus_108.nii.gz',
#  'hippocampus_070.nii.gz',
#  'hippocampus_329.nii.gz',
#  'hippocampus_107.nii.gz',
#  'hippocampus_090.nii.gz',
#  'hippocampus_092.nii.gz',
#  'hippocampus_318.nii.gz',
#  'hippocampus_333.nii.gz',
#  'hippocampus_123.nii.gz',
#  'hippocampus_037.nii.gz',
#  'hippocampus_023.nii.gz',
#  'hippocampus_330.nii.gz',
#  'hippocampus_374.nii.gz',
#  'hippocampus_380.nii.gz',
#  'hippocampus_056.nii.gz',
#  'hippocampus_040.nii.gz',
#  'hippocampus_127.nii.gz',
#  'hippocampus_163.nii.gz',
#  'hippocampus_146.nii.gz',
#  'hippocampus_050.nii.gz',
#  'hippocampus_279.nii.gz',
#  'hippocampus_224.nii.gz',
#  'hippocampus_301.nii.gz',
#  'hippocampus_160.nii.gz',
#  'hippocampus_352.nii.gz',
#  'hippocampus_114.nii.gz',
#  'hippocampus_236.nii.gz',
#  'hippocampus_170.nii.gz',
#  'hippocampus_077.nii.gz',
#  'hippocampus_173.nii.gz',
#  'hippocampus_049.nii.gz',
#  'hippocampus_292.nii.gz',
#  'hippocampus_229.nii.gz',
#  'hippocampus_335.nii.gz',
#  'hippocampus_253.nii.gz',
#  'hippocampus_263.nii.gz',
#  'hippocampus_314.nii.gz',
#  'hippocampus_355.nii.gz',
#  'hippocampus_221.nii.gz',
#  'hippocampus_320.nii.gz',
#  'hippocampus_011.nii.gz',
#  'hippocampus_098.nii.gz',
#  'hippocampus_161.nii.gz',
#  'hippocampus_102.nii.gz',
#  'hippocampus_154.nii.gz',
#  'hippocampus_157.nii.gz',
#  'hippocampus_274.nii.gz',
#  'hippocampus_327.nii.gz',
#  'hippocampus_297.nii.gz',
#  'hippocampus_215.nii.gz',
#  'hippocampus_074.nii.gz',
#  'hippocampus_242.nii.gz',
#  'hippocampus_319.nii.gz',
#  'hippocampus_046.nii.gz',
#  'hippocampus_034.nii.gz',
#  'hippocampus_223.nii.gz',
#  'hippocampus_328.nii.gz',
#  'hippocampus_038.nii.gz',
#  'hippocampus_180.nii.gz',
#  'hippocampus_220.nii.gz',
#  'hippocampus_383.nii.gz',
#  'hippocampus_244.nii.gz',
#  'hippocampus_277.nii.gz',
#  'hippocampus_083.nii.gz',
#  'hippocampus_010.nii.gz',
#  'hippocampus_042.nii.gz',
#  'hippocampus_349.nii.gz',
#  'hippocampus_300.nii.gz',
#  'hippocampus_164.nii.gz',
#  'hippocampus_303.nii.gz',
#  'hippocampus_326.nii.gz',
#  'hippocampus_124.nii.gz',
#  'hippocampus_268.nii.gz',
#  'hippocampus_222.nii.gz',
#  'hippocampus_053.nii.gz',
#  'hippocampus_172.nii.gz',
#  'hippocampus_156.nii.gz',
#  'hippocampus_136.nii.gz',
#  'hippocampus_177.nii.gz',
#  'hippocampus_181.nii.gz',
#  'hippocampus_354.nii.gz',
#  'hippocampus_359.nii.gz',
#  'hippocampus_141.nii.gz',
#  'hippocampus_356.nii.gz',
#  'hippocampus_325.nii.gz',
#  'hippocampus_210.nii.gz']

# %%
# TASK: Your data sits in directory /data/TrainingSet.
# Load an image and a segmentation mask into variables called image and label
data_dir = '../../data/TrainingSet'
image_path = os.path.join(data_dir, 'images')
label_path = os.path.join(data_dir, 'labels')

images = sorted(glob.glob(os.path.join(image_path, '*.nii.gz')))
labels = sorted(glob.glob(os.path.join(label_path, '*.nii.gz')))

len(images), len(labels)
# Out:
# (263, 262)

# %%
# Find image without label
outliers = []
for img in images: 
    img_path = img
    img_name = img.split(os.sep)[-1]
    expected_label_name = os.path.join(label_path, img_name)
    if not os.path.exists(expected_label_name):
        print('outlier found: ', img_name)
        outliers.append(img_name)
        images.remove(img_path)
        
len(images), len(labels), len(outliers)
# Out:
# outlier found:  hippocampus_118.nii.gz
# (262, 262, 1)

# %%
# Find image with strange number of slices
outliers = [] 
threshold = 60

for img in images: 
    
    img_x, img_y, img_z = nib.load(img).get_fdata().shape
    
    if (img_x > threshold) | (img_y > threshold) | (img_z > threshold):        
        outliers.append(img)
        img_name = img.split(os.sep)[-1]
        images.remove(img)
        labels.remove(os.path.join(label_path, img_name))
        print('outlier found: ', img_name)
        print(img_x, img_y, img_z)
        
len(images), len(labels), len(outliers)
# Out:
# outlier found:  hippocampus_010.nii.gz
# 512 512 241
# outlier found:  hippocampus_281.nii.gz
# 512 512 31
# (260, 260, 2)

# %%
image = nib.load(images[0]).get_fdata()
label = nib.load(labels[0]).get_fdata()

print(image.shape, label.shape)
# Out:
# (35, 51, 35) (35, 51, 35)

# %%
# Nibabel can present your image data as a Numpy array by calling the method get_fdata()
# The array will contain a multi-dimensional Numpy array with numerical values representing voxel intensities. 
# In our case, images and labels are 3-dimensional, so get_fdata will return a 3-dimensional array. You can verify this
# by accessing the .shape attribute. What are the dimensions of the input arrays?

# TASK: using matplotlib, visualize a few slices from the dataset, along with their labels. 
# You can adjust plot sizes like so if you find them too small:
# plt.rcParams["figure.figsize"] = (10,10)

# %%
fig, ax = plt.subplots(5, 7*2, figsize=[30,30])

for i in range(35):
    if (i < len(image)):
        ax[int(i/7), 2*int(i%7)].set_title(f"Slice {i}")
        ax[int(i/7), 2*int(i%7)].imshow(image[i], cmap='gray')

        ax[int(i/7), 2*int(i%7) + 1].set_title(f"Label {i}")
        ax[int(i/7), 2*int(i%7) + 1].imshow(label[i], cmap='gray')

        ax[int(i/7), 2*int(i%7)].axis("off")
        ax[int(i/7), 2*int(i%7)+1].axis("off")

plt.show()

# %% [markdown]
# Load volume into 3D Slicer to validate that your visualization is correct and get a feel for the shape of structures.Try to get a visualization like the one below (hint: while Slicer documentation is not particularly great, there are plenty of YouTube videos available! Just look it up on YouTube if you are not sure how to do something)
#
# ![3D slicer](img/Slicer.png)

# %%
# Stand out suggestion: use one of the simple Volume Rendering algorithms that we've
# implemented in one of our earlier lessons to visualize some of these volumes

# %% [markdown]
# ## Looking at single image data
# In this section we will look closer at the NIFTI representation of our volumes. In order to measure the physical volume of hippocampi, we need to understand the relationship between the sizes of our voxels and the physical world.

# %%
# Nibabel supports many imaging formats, NIFTI being just one of them. I told you that our images 
# are in NIFTI, but you should confirm if this is indeed the format that we are dealing with
# TASK: using .header_class attribute - what is the format of our images?

img = nib.load(images[0])
print('Format of the image:', img.header_class)
img.header.keys()
# Out:
# Format of the image: <class 'nibabel.nifti1.Nifti1Header'>
# ['sizeof_hdr',
#  'data_type',
#  'db_name',
#  'extents',
#  'session_error',
#  'regular',
#  'dim_info',
#  'dim',
#  'intent_p1',
#  'intent_p2',
#  'intent_p3',
#  'intent_code',
#  'datatype',
#  'bitpix',
#  'slice_start',
#  'pixdim',
#  'vox_offset',
#  'scl_slope',
#  'scl_inter',
#  'slice_end',
#  'slice_code',
#  'xyzt_units',
#  'cal_max',
#  'cal_min',
#  'slice_duration',
#  'toffset',
#  'glmax',
#  'glmin',
#  'descrip',
#  'aux_file',
#  'qform_code',
#  'sform_code',
#  'quatern_b',
#  'quatern_c',
#  'quatern_d',
#  'qoffset_x',
#  'qoffset_y',
#  'qoffset_z',
#  'srow_x',
#  'srow_y',
#  'srow_z',
#  'intent_name',
#  'magic']

# %% [markdown]
# Further down we will be inspecting .header attribute that provides access to NIFTI metadata. You can use this resource as a reference for various fields: https://brainder.org/2012/09/23/the-nifti-file-format/

# %%
# TASK: How many bits per pixel are used?
print('Bits per pixel:', img.header['bitpix'])
# Out:
# Bits per pixel: 8

# %%
# TASK: What are the units of measurement?
print('Units per measurement:', img.header['xyzt_units'])
# Out:
# Units per measurement: 10

# %%
# TASK: Do we have a regular grid? What are grid spacings?
print('Grid spacing:', img.header['pixdim'])
# Out:
# Grid spacing: [1. 1. 1. 1. 1. 0. 0. 0.]

# %%
# TASK: What dimensions represent axial, sagittal, and coronal slices? How do you know?
print('Dimensions:', img.header['dim'])
# Out:
# Dimensions: [ 3 35 51 35  1  1  1  1]

# %% [markdown]
# The convension:
# - dim[1] is sagittal plane
# - dim[2] is coronal plane
# - dim[3] is axial plane

# %%
# By now you should have enough information to decide what are dimensions of a single voxel
# TASK: Compute the volume (in mm³) of a hippocampus using one of the labels you've loaded. 
# You should get a number between ~2200 and ~4500

# %%
def volume_calc(index): 
    return np.sum(nib.load(labels[index]).get_fdata() != 0)

# %%
print('Hippocamus volume:', volume_calc(0))
# Out:
# Hippocamus volume: 2948

# %% [markdown]
# ## Plotting some charts

# %%
# TASK: Plot a histogram of all volumes that we have in our dataset and see how 
# our dataset measures against a slice of a normal population represented by the chart below.

# %%
volume = [volume_calc(i) for i in range(len(labels))]

plt.hist(volume, bins=50)
plt.xlabel('Volume (mm^3)')
plt.show()

# %% [markdown]
# <img src="img/nomogram_fem_right.svg" width=400 align=left>

# %% [markdown]
# Do you see any outliers? Why do you think it's so (might be not immediately obvious, but it's always a good idea to inspect) outliers closer. If you haven't found the images that do not belong, the histogram may help you.

# %% [markdown]
# In the real world we would have precise information about the ages and conditions of our patients, and understanding how our dataset measures against population norm would be the integral part of clinical validation that we talked about in last lesson. Unfortunately, we do not have this information about this dataset, so we can only guess why it measures the way it is. If you would like to explore further, you can use the [calculator from HippoFit project](http://www.smanohar.com/biobank/calculator.html) to see how our dataset compares against different population slices

# %% [markdown]
# Did you notice anything odd about the label files? We hope you did! The mask seems to have two classes, labeled with values `1` and `2` respectively. If you visualized sagittal or axial views, you might have gotten a good guess of what those are. Class 1 is the anterior segment of the hippocampus and class 2 is the posterior one.
#
# For the purpose of volume calculation we do not care about the distinction, however we will still train our network to differentiate between these two classes and the background

# %%
# TASK: Copy the clean dataset to the output folder inside section1/out. You will use it in the next Section
for f in images: 
    shutil.copy(f, "out/images")
for f in labels: 
    shutil.copy(f, "out/labels")
# Out:
# saving ../../data/TrainingSet/images/hippocampus_001.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_003.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_004.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_006.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_007.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_008.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_011.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_014.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_015.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_017.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_019.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_020.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_023.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_024.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_025.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_026.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_033.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_034.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_035.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_036.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_037.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_038.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_039.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_040.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_041.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_042.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_044.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_045.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_046.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_048.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_049.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_050.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_051.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_052.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_053.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_056.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_057.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_058.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_060.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_064.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_065.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_067.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_068.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_070.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_074.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_075.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_077.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_083.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_084.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_087.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_088.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_089.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_090.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_091.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_092.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_093.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_094.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_095.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_096.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_097.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_098.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_099.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_101.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_102.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_104.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_105.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_106.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_107.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_108.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_109.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_114.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_123.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_124.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_125.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_126.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_127.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_130.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_132.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_133.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_135.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_136.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_138.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_141.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_142.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_143.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_144.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_145.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_146.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_148.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_149.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_150.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_152.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_154.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_155.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_156.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_157.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_158.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_160.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_161.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_162.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_163.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_164.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_165.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_166.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_169.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_170.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_171.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_172.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_173.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_174.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_175.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_176.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_177.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_178.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_180.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_181.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_184.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_185.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_188.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_189.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_190.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_193.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_194.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_195.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_197.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_199.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_203.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_204.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_205.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_207.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_210.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_212.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_215.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_216.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_217.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_219.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_220.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_221.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_222.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_223.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_224.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_225.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_226.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_227.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_228.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_229.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_230.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_231.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_232.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_233.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_234.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_235.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_236.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_238.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_242.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_243.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_244.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_245.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_248.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_249.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_250.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_251.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_252.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_253.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_257.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_259.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_260.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_261.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_263.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_264.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_265.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_268.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_269.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_274.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_276.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_277.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_279.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_280.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_282.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_286.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_287.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_288.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_289.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_290.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_292.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_294.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_295.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_296.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_297.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_298.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_299.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_300.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_301.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_302.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_303.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_304.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_305.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_308.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_309.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_310.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_311.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_314.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_316.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_317.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_318.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_319.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_320.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_321.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_322.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_325.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_326.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_327.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_328.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_329.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_330.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_331.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_332.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_333.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_334.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_335.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_336.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_337.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_338.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_340.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_341.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_343.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_345.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_349.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_350.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_351.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_352.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_353.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_354.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_355.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_356.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_358.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_359.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_360.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_361.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_363.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_366.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_367.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_368.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_370.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_372.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_373.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_374.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_375.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_376.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_378.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_380.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_381.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_383.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_385.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_386.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_387.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_389.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_390.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_393.nii.gz out/images
# saving ../../data/TrainingSet/images/hippocampus_394.nii.gz out/images

# %% [markdown]
# ## Final remarks
#
# Congratulations! You have finished Section 1.
#
# In this section you have inspected a dataset of MRI scans and related segmentations, represented as NIFTI files. We have visualized some slices, and understood the layout of the data. We have inspected file headers to understand what how the image dimensions relate to the physical world and we have understood how to measure our volume. We have then inspected dataset for outliers, and have created a clean set that is ready for consumption by our ML algorithm.
#
# In the next section you will create training and testing pipelines for a UNet-based machine learning model, run and monitor the execution, and will produce test metrics. This will arm you with all you need to use the model in the clinical context and reason about its performance!
